# %% [markdown]
# # Intro notebook to the dense Self-Organizing-Feature layer

# %% [markdown]
# ## Import and setup

# %%
# %env TF_CPP_MIN_LOG_LEVEL=3

import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds
# Out:
# env: TF_CPP_MIN_LOG_LEVEL=3

# %% [markdown]
# ## Load and preprocess the dataset

# %%
(ds_train, ds_test), ds_info = tfds.load(
    "mnist",
    split=["train", "test"],
    shuffle_files=True,
    as_supervised=True,
    with_info=True,
)


def normalize_img(image, label):
    """Normalizes images: `uint8` -> `float32`."""
    return tf.reshape(tf.cast(image, tf.float32) / 255.0, (28, 28, 1)), label


# train dataset
ds_train = ds_train.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.cache()
ds_train = ds_train.shuffle(ds_info.splits["train"].num_examples)
ds_train = ds_train.batch(128)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

# test_dataset:
ds_test = ds_test.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_test = ds_test.batch(128)
ds_test = ds_test.cache()
ds_test = ds_test.prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# ## Define the dense layer with Self-Organinzing-Feature concept

# %%
class DenseSOCLayer(tf.keras.layers.Layer):
    def __init__(self, features=32, **kwargs):
        super().__init__(**kwargs)
        self.features = features

    def build(self, input_shape):
        self.projection = self.add_weight(
            shape=(self.features, input_shape[-1]),
            initializer=tf.keras.initializers.VarianceScaling(
                scale=1.0, mode="fan_out", distribution="uniform", seed=None
            ),
            trainable=True,
        )
        self.scale_diag = self.add_weight(
            shape=(self.features, input_shape[-1]),
            initializer="ones",
            trainable=True,
        )

    @staticmethod
    def _log_prob(mu, scale_diag, x, unnormalized):
        log_unnormalized = -0.5 * tf.math.squared_difference(
            x / scale_diag, mu / scale_diag
        )
        if unnormalized:
            return tf.reduce_sum(log_unnormalized)
        log_normalization = tf.constant(
            0.5 * np.log(2.0 * np.pi), dtype=mu.dtype
        ) + tf.math.log(scale_diag)
        return tf.reduce_sum(log_unnormalized - log_normalization)

    def log_prob(self, mu, scale_diag, x, unnormalized=True):
        batch_log_prob = tf.vectorized_map(
            lambda _x: tf.vectorized_map(
                lambda _params: self._log_prob(
                    _params[0], _params[1], _x, unnormalized=unnormalized
                ),
                (mu, scale_diag),
            ),
            x,
        )
        return batch_log_prob

    def call(self, inputs):
        log_probs = self.log_prob(self.projection, self.scale_diag, inputs)
        return log_probs

# %% [markdown]
# ## Define the model with a single SOF layer

# %%
model = tf.keras.models.Sequential(
    [
        tf.keras.layers.Flatten(input_shape=(28, 28, 1)),
        tf.keras.layers.Dense(40),
        tf.keras.layers.LayerNormalization(),
        DenseSOCLayer(features=10),
        tf.keras.layers.LayerNormalization(),
        tf.keras.layers.Dense(10),
    ]
)

model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
    run_eagerly=False,
)
model.summary()

model.fit(
    ds_train,
    epochs=15,
    validation_data=ds_test,
    verbose=2,
)

print("\nEval:")
_ = model.evaluate(ds_test, verbose=2)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 40)                31400
#
#  layer_normalization (LayerN  (None, 40)               80
#  ormalization)
#
#  dense_soc_layer (DenseSOCLa  (None, 10)               800
#  yer)
#
#  layer_normalization_1 (Laye  (None, 10)               20
#  rNormalization)
#
#  dense_1 (Dense)             (None, 10)                110
#
# =================================================================
# Total params: 32,410
# Trainable params: 32,410
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 469/469 - 6s - loss: 0.5784 - sparse_categorical_accuracy: 0.8710 - val_loss: 0.2315 - val_sparse_categorical_accuracy: 0.9456 - 6s/epoch - 12ms/step
# Epoch 2/15
# 469/469 - 1s - loss: 0.1855 - sparse_categorical_accuracy: 0.9520 - val_loss: 0.1465 - val_sparse_categorical_accuracy: 0.9603 - 1s/epoch - 2ms/step
# Epoch 3/15
# 469/469 - 1s - loss: 0.1266 - sparse_categorical_accuracy: 0.9650 - val_loss: 0.1188 - val_sparse_categorical_accuracy: 0.9666 - 1s/epoch - 2ms/step
# Epoch 4/15
# 469/469 - 1s - loss: 0.0989 - sparse_categorical_accuracy: 0.9711 - val_loss: 0.1171 - val_sparse_categorical_accuracy: 0.9657 - 1s/epoch - 2ms/step
# Epoch 5/15
# 469/469 - 1s - loss: 0.0826 - sparse_categorical_accuracy: 0.9757 - val_loss: 0.1034 - val_sparse_categorical_accuracy: 0.9696 - 1s/epoch - 2ms/step
# Epoch 6/15
# 469/469 - 1s - loss: 0.0709 - sparse_categorical_accuracy: 0.9796 - val_loss: 0.1029 - val_sparse_categorical_accuracy: 0.9701 - 1s/epoch - 2ms/step
# Epoch 7/15
# 469/469 - 1s - loss: 0.0618 - sparse_categorical_accuracy: 0.9816 - val_loss: 0.0956 - val_sparse_categorical_accuracy: 0.9721 - 1s/epoch - 2ms/step
# Epoch 8/15
# 469/469 - 1s - loss: 0.0558 - sparse_categorical_accuracy: 0.9834 - val_loss: 0.0974 - val_sparse_categorical_accuracy: 0.9704 - 1s/epoch - 2ms/step
# Epoch 9/15
# 469/469 - 1s - loss: 0.0492 - sparse_categorical_accuracy: 0.9855 - val_loss: 0.1028 - val_sparse_categorical_accuracy: 0.9722 - 1s/epoch - 2ms/step
# Epoch 10/15
# 469/469 - 1s - loss: 0.0431 - sparse_categorical_accuracy: 0.9873 - val_loss: 0.1029 - val_sparse_categorical_accuracy: 0.9716 - 1s/epoch - 2ms/step
# Epoch 11/15
# 469/469 - 1s - loss: 0.0407 - sparse_categorical_accuracy: 0.9880 - val_loss: 0.1027 - val_sparse_categorical_accuracy: 0.9704 - 1s/epoch - 2ms/step
# Epoch 12/15
# 469/469 - 1s - loss: 0.0367 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.0992 - val_sparse_categorical_accuracy: 0.9738 - 1s/epoch - 2ms/step
# Epoch 13/15
# 469/469 - 1s - loss: 0.0335 - sparse_categorical_accuracy: 0.9898 - val_loss: 0.1096 - val_sparse_categorical_accuracy: 0.9698 - 1s/epoch - 2ms/step
# Epoch 14/15
# 469/469 - 1s - loss: 0.0308 - sparse_categorical_accuracy: 0.9905 - val_loss: 0.1029 - val_sparse_categorical_accuracy: 0.9737 - 1s/epoch - 2ms/step
# Epoch 15/15
# 469/469 - 1s - loss: 0.0289 - sparse_categorical_accuracy: 0.9910 - val_loss: 0.1117 - val_sparse_categorical_accuracy: 0.9717 - 1s/epoch - 2ms/step
#
# Eval:
# 79/79 - 0s - loss: 0.1117 - sparse_categorical_accuracy: 0.9717 - 86ms/epoch - 1ms/step

# %% [markdown]
# ## Define baseline model without SOF layer.
# ### The layer replacing it has twice as many features to have the same parameter count.

# %%
model = tf.keras.models.Sequential(
    [
        tf.keras.layers.Flatten(input_shape=(28, 28, 1)),
        tf.keras.layers.Dense(40, activation="relu"),
        tf.keras.layers.LayerNormalization(),
        tf.keras.layers.Dense(20, activation="relu"),  # I double the features to have the ~same parameter count.
        tf.keras.layers.LayerNormalization(),
        tf.keras.layers.Dense(10),
    ]
)
model.compile(
    optimizer=tf.keras.optimizers.Adam(0.001),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

model.summary()

model.fit(
    ds_train,
    epochs=15,
    validation_data=ds_test,
    verbose=2,
)

print("\nEval:")
_ = model.evaluate(ds_test, verbose=2)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 40)                31400
#
#  layer_normalization_2 (Laye  (None, 40)               80
#  rNormalization)
#
#  dense_3 (Dense)             (None, 20)                820
#
#  layer_normalization_3 (Laye  (None, 20)               40
#  rNormalization)
#
#  dense_4 (Dense)             (None, 10)                210
#
# =================================================================
# Total params: 32,550
# Trainable params: 32,550
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/15
# 469/469 - 2s - loss: 0.4565 - sparse_categorical_accuracy: 0.8799 - val_loss: 0.2040 - val_sparse_categorical_accuracy: 0.9418 - 2s/epoch - 5ms/step
# Epoch 2/15
# 469/469 - 1s - loss: 0.1707 - sparse_categorical_accuracy: 0.9514 - val_loss: 0.1514 - val_sparse_categorical_accuracy: 0.9562 - 993ms/epoch - 2ms/step
# Epoch 3/15
# 469/469 - 1s - loss: 0.1258 - sparse_categorical_accuracy: 0.9633 - val_loss: 0.1278 - val_sparse_categorical_accuracy: 0.9629 - 965ms/epoch - 2ms/step
# Epoch 4/15
# 469/469 - 1s - loss: 0.1015 - sparse_categorical_accuracy: 0.9698 - val_loss: 0.1348 - val_sparse_categorical_accuracy: 0.9605 - 971ms/epoch - 2ms/step
# Epoch 5/15
# 469/469 - 1s - loss: 0.0882 - sparse_categorical_accuracy: 0.9737 - val_loss: 0.1137 - val_sparse_categorical_accuracy: 0.9661 - 995ms/epoch - 2ms/step
# Epoch 6/15
# 469/469 - 1s - loss: 0.0775 - sparse_categorical_accuracy: 0.9766 - val_loss: 0.1126 - val_sparse_categorical_accuracy: 0.9666 - 988ms/epoch - 2ms/step
# Epoch 7/15
# 469/469 - 1s - loss: 0.0677 - sparse_categorical_accuracy: 0.9793 - val_loss: 0.1070 - val_sparse_categorical_accuracy: 0.9683 - 1s/epoch - 2ms/step
# Epoch 8/15
# 469/469 - 1s - loss: 0.0623 - sparse_categorical_accuracy: 0.9812 - val_loss: 0.1027 - val_sparse_categorical_accuracy: 0.9701 - 966ms/epoch - 2ms/step
# Epoch 9/15
# 469/469 - 1s - loss: 0.0560 - sparse_categorical_accuracy: 0.9830 - val_loss: 0.1013 - val_sparse_categorical_accuracy: 0.9707 - 992ms/epoch - 2ms/step
# Epoch 10/15
# 469/469 - 1s - loss: 0.0504 - sparse_categorical_accuracy: 0.9847 - val_loss: 0.1097 - val_sparse_categorical_accuracy: 0.9690 - 1s/epoch - 2ms/step
# Epoch 11/15
# 469/469 - 1s - loss: 0.0485 - sparse_categorical_accuracy: 0.9844 - val_loss: 0.1006 - val_sparse_categorical_accuracy: 0.9707 - 989ms/epoch - 2ms/step
# Epoch 12/15
# 469/469 - 1s - loss: 0.0442 - sparse_categorical_accuracy: 0.9866 - val_loss: 0.1141 - val_sparse_categorical_accuracy: 0.9692 - 994ms/epoch - 2ms/step
# Epoch 13/15
# 469/469 - 1s - loss: 0.0412 - sparse_categorical_accuracy: 0.9867 - val_loss: 0.1108 - val_sparse_categorical_accuracy: 0.9683 - 987ms/epoch - 2ms/step
# Epoch 14/15
# 469/469 - 1s - loss: 0.0354 - sparse_categorical_accuracy: 0.9891 - val_loss: 0.1057 - val_sparse_categorical_accuracy: 0.9708 - 981ms/epoch - 2ms/step
# Epoch 15/15
# 469/469 - 1s - loss: 0.0342 - sparse_categorical_accuracy: 0.9895 - val_loss: 0.1076 - val_sparse_categorical_accuracy: 0.9711 - 985ms/epoch - 2ms/step
#
# Eval:
# 79/79 - 0s - loss: 0.1076 - sparse_categorical_accuracy: 0.9711 - 82ms/epoch - 1ms/step
